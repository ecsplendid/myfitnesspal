# %%
from pandas import read_csv
from pipe import *
from dfply import *
import matplotlib.pyplot as plt

df = (read_csv('Nutrition.csv') >>
 mask(X.Date > '2016-01-01') >>
 arrange(X.Date) >>
 group_by(X.Date) 
)

df.columns = ['Date', 'Meal', 'Calories', 'Fat', 'SaturatedFat',
       'PolyunsaturatedFat', 'MonounsaturatedFat', 'TransFat',
       'Cholesterol', 'Sodium', 'Potassium', 'Carbohydrates', 'Fiber',
       'Sugar', 'Protein', 'VitaminA', 'VitaminC', 'Calcium', 'Iron']

df >> summarize(Protein=X.Protein.sum())
# Out:
#            Date  Protein
# 0    2016-03-13    125.9
# 1    2016-03-14    134.4
# 2    2016-03-15    132.6
# 3    2016-03-16    134.5
# 4    2016-03-17    128.2
# 5    2016-03-18     97.2
# 6    2016-03-19    180.0
# 7    2016-03-20    135.0
# 8    2016-03-21     66.1
# 9    2016-03-22    142.7
# 10   2016-03-23    158.0
# 11   2016-03-24     24.5
# 12   2016-03-25    153.2
# 13   2016-03-26     63.7
# 14   2016-03-27    160.1
# 15   2016-03-28    127.5
# 16   2016-03-29     62.6
# 17   2016-03-30    189.6
# 18   2016-03-31    102.3
# 19   2016-04-01     78.0
# 20   2016-04-02    147.5
# 21   2016-04-03    144.9
# 22   2016-04-04    115.7
# 23   2016-04-05    112.4
# 24   2016-04-06     78.4
# 25   2016-04-07    186.9
# 26   2016-04-08    139.4
# 27   2016-04-09     17.9
# 28   2016-04-10    228.5
# 29   2016-04-11    150.5
# ..          ...      ...
# 685  2018-02-02    144.4
# 686  2018-02-03     73.6
# 687  2018-02-04    116.7
# 688  2018-02-05    179.2
# 689  2018-02-06    129.3
# ...

# %%
p=plt.plot(df['Protein'])
t=plt.xticks(rotation='vertical')
